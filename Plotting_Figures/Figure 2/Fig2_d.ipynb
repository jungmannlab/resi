# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Apr  1 13:36:09 2022

@author: masullo, steen
"""
#%matplotlib inline
# %matplotlib qt

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import cm

plt.close('all')

path = '/Volumes/pool-miblab4/users/reinhardt/z_raw/Resi/220125_Nup96-GFP_4c/aligned/philipp/fig2_pick_clusters/'

fname_noncluster = {}
fname_cluster = {}

fname_noncluster['R1'] = 'R1_7nt_150pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'
fname_cluster['R1'] = 'R1_7nt_150pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'

fname_noncluster['R2'] = 'R2_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'
fname_cluster['R2'] = 'R2_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'

fname_noncluster['R3'] = 'R3_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'
fname_cluster['R3'] = 'R3_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'

fname_noncluster['R4'] = 'R4_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'
fname_cluster['R4'] = 'R4_7nt_100pM_18mW_150ms_561_1_MMStack_Pos0.ome_locs_render_render_filter_aligned_apicked_ClusterD11_10_22.0_apicked.hdf5'

px_size = 130 # nm

locs_nc_x = {}
locs_nc_y = {}
locs_nc_z = {}

locs_c_x = {}
locs_c_y = {}
locs_c_z = {}

display_xlocs_c = {}
display_ylocs_c = {}
display_zlocs_c = {}

display_xlocs_nc = {}
display_ylocs_nc = {}
display_zlocs_nc = {}

z_min = 1000
z_max = 0

for i, ch in enumerate(['R1', 'R2', 'R3', 'R4']):
    
    my_df_noncluster = pd.read_hdf(path + fname_noncluster[ch], key='locs')
    my_df_cluster = pd.read_hdf(path + fname_cluster[ch], key='locs')  

    my_df_noncluster.x = my_df_noncluster.x * px_size
    my_df_noncluster.y = my_df_noncluster.y * px_size
    
    my_df_noncluster.y = my_df_noncluster.y*(-1)
    
    my_df_cluster.x = my_df_cluster.x * px_size
    my_df_cluster.y = my_df_cluster.y * px_size
    
    my_df_cluster.y = my_df_cluster.y*(-1)
    
    locs_nc_x[ch] = my_df_noncluster.x
    locs_nc_y[ch] = my_df_noncluster.y
    locs_nc_z[ch] = my_df_noncluster.z
    
    locs_c_x[ch] = my_df_cluster.x
    locs_c_y[ch] = my_df_cluster.y
    locs_c_z[ch] = my_df_cluster.z
    
    current_min = np.min(my_df_cluster.z)
    current_max = np.max(locs_c_z[ch])
    
    if current_min < z_min:
        z_min = current_min
    if current_max > z_max:
        z_max = current_max

#for i, ch in enumerate(['R1', 'R2', 'R3', 'R4']):
#    locs_c_z[ch] = locs_c_z[ch] + abs(z_min)
#    current_max = np.max(locs_c_z[ch])
#    if current_max > z_max:
#        z_max = current_max

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(14,14))
ax.set_aspect('equal')

Farben = cm.get_cmap('rainbow', 1000)
    
colors = ['#CC99C9', '#9EC1CF', '#9EE09E', '#FEB144']
display3d = False

if display3d:
    
    #TODO: fix 3D visualization
    
    for i, ch in enumerate(['R1', 'R2', 'R3', 'R4']):
        
        ax = fig.add_subplot(projection='3d')
        
        #xmin, xmax = 32680, 32840
        #ymin, ymax = 38500, 38660
        roi = (locs_nc_y[ch] > ymin) & (locs_nc_y[ch] < ymax) & (locs_nc_x[ch] > xmin) & (locs_nc_x[ch] < xmax)
        
        display_xlocs_nc[ch] = locs_nc_x[ch][roi]
        # display_xlocs_c[ch] = locs_c_x[ch][roi]

        display_ylocs_nc[ch] = locs_nc_y[ch][roi]
        # display_ylocs_c[ch] = locs_c_y[ch][roi]
        
        display_zlocs_nc[ch] = locs_nc_z[ch][roi]
        # display_zlocs_c[ch] = locs_c_z[ch][roi]

        
        ax.scatter(display_xlocs_nc[ch], display_ylocs_nc[ch], display_zlocs_nc[ch], color=colors[i], edgecolors='white', alpha=0.3)
        # ax.scatter(display_xlocs_c[ch], display_ylocs_c[ch], display_zlocs_c[ch], color=colors[i], edgecolors='white')
        # ax.set_xlim(32000, 33000)
        # ax.set_ylim(35000, 36000)
    
else:

    for i, ch in enumerate(['R1', 'R2', 'R3', 'R4']):
        
        fig, ax = plt.subplots(figsize=(14,14))
        ax.set_aspect('equal')
        #ax.scatter(locs_nc_x[ch], locs_nc_y[ch], color=colors[i], edgecolors='white', alpha=0.3)
        #ax.scatter(locs_c_x[ch], locs_c_y[ch], color=colors[i], edgecolors='white')
        
        #ax = fig.add_subplot(2,2,i+1)
        ax.scatter(locs_c_x[ch], locs_c_y[ch], c=locs_c_z[ch], cmap=Farben, vmin = z_min, vmax = z_max, s=50)
        #ax.scatter(locs_c_x[ch], locs_c_y[ch], c=locs_c_z[ch], cmap=Farben, s=40)
        
        ax.set_xlim(32680, 32840)
        ax.set_ylim(-38650, -38490)
        
        plt.savefig(ch+"_with_z.pdf", transparent=True)
        
        plt.clf()
        
        plt.show()
        
        #plt.show()
